# %%
1. What is Object-Oriented Programming (OOP)+

# %% [markdown]
# - Object-Oriented Programming (OOP) is a programming paradigm that organizes code around objects rather than functions and logic.
#
# - Objects represent real-world entities (like a car, person, or bank account).
#
# - Each object can have attributes (data) and methods (functions/behavior).

# %% [markdown]
# 2. What is a class in OOP?

# %% [markdown]
# -  Object-Oriented Programming (OOP), a class is a blueprint or template used to create objects.

# %% [markdown]
# 3. What is an object in OOP?

# %% [markdown]
# - In Object-Oriented Programming (OOP), an object is an instance of a class.

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?

# %% [markdown]
# - **Abstraction** : Abstraction means hiding the complex implementation details and showing only the essential features of an object.
# - It focuses on what an object does, not how it does it.
#
# - **Encapsulation**: Encapsulation means bundling data (attributes) and methods (functions) together into a single unit (class),
# and restricting direct access to some of the object’s data for security and control.
# - It focuses on how to protect the data.

# %% [markdown]
# 5.What are dunder methods in Python?

# %% [markdown]
# - Dunder methods are predefined methods in Python classes that allow you to customize the behavior of your objects.
# They make your classes behave more like built-in types.
# - In Python, dunder methods (also called magic methods or special methods) are the built-in methods that start and end with double underscores — for example, __init__, __str__, __len__, etc.

# %% [markdown]
# 6. Explain the concept of inheritance in OOP.

# %% [markdown]
# - Inheritance means creating a new class (child/subclass) from an existing class (parent/superclass)
# so that the child class automatically gets all the parent’s attributes and methods — and can add or modify them.

# %% [markdown]
# 7. What is polymorphism in OOP?

# %% [markdown]
# - Polymorphism means “many forms.”
# It allows different classes to use the same method name, but each class can behave differently when that method is called.

# %% [markdown]
# 8. How is encapsulation achieved in Python?

# %% [markdown]
# - In Python, encapsulation is achieved by restricting direct access to an object’s internal data and methods — and instead providing controlled access through public methods (like getters and setters).
#
# It’s one of the core principles of OOP, helping in data protection and code organization.

# %% [markdown]
# 9. What is a constructor in Python?

# %% [markdown]
# - In Python, a constructor is a special method that is automatically called when a new object of a class is created.

# %% [markdown]
# 10. What are class and static methods in Python?

# %% [markdown]
# - **Class Method**
#
# - Belongs to the class, not the instance.
#
# - Works with class variables, not instance variables.
#
# - Takes cls (class reference) as the first parameter.
#
# - Defined using the @classmethod decorator.

# %% [markdown]
# - **Static Method**
#
# - Does not depend on the class or instance.
#
# - Does not take self or cls as arguments.
#
# - It’s just a utility function inside a class (logically related, but independent).
#
# - Defined using the @staticmethod decorator.

# %% [markdown]
# 11. What is method overloading in Python?

# %% [markdown]
# - Method Overloading in Python refers to defining multiple methods with the same name but different parameters (number or type of arguments).

# %% [markdown]
# 12.  What is method overriding in OOP?

# %% [markdown]
# - Method Overriding in Object-Oriented Programming (OOP) happens when a child (subclass) defines a method that already exists in its parent (superclass) — but with a new or modified implementation.

# %% [markdown]
# 13.What is a property decorator in Python?

# %% [markdown]
# - The property decorator in Python is used to turn a method into a “read-only” attribute — allowing you to access it like an attribute but compute it like a method.

# %% [markdown]
# 14. Why is polymorphism important in OOP?

# %% [markdown]
# - The word polymorphism means “many forms”, and in OOP, it allows different classes to use methods with the same name but behave differently.

# %% [markdown]
# 15.  What is an abstract class in Python?

# %% [markdown]
# - An abstract class in Python is a blueprint for other classes.
# It defines methods that must be implemented by its child (sub) classes, but it cannot be instantiated (you can’t create objects directly from it).

# %% [markdown]
# 16. What are the advantages of OOP?

# %% [markdown]
# - OOP (Object-Oriented Programming) organizes code around objects — which combine data (attributes) and behavior (methods) into one logical unit.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable?

# %% [markdown]
# **Class Variable**
# - A class variable is shared by all objects (instances) of a class.
# It belongs to the class itself, not to any one object.
#
# - Defined outside any method, usually right after the class definition.
#
# - Changing it affects all instances of that class.
#
# **instance variable**
# - An instance variable is unique to each object (instance).
# It belongs to the object, not the class.
#
# - Defined inside the constructor (__init__) using self.
#
# - Each object has its own copy of instance variables.

# %% [markdown]
# 18. What is multiple inheritance in Python?

# %% [markdown]
# - Multiple Inheritance means a class can inherit from more than one parent class.
#
# In other words, a child class can access attributes and methods from multiple base (parent) classes.

# %% [markdown]
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.

# %% [markdown]
# - In Python, __str__() and __repr__() are special (dunder) methods that define how objects are represented as strings.
# - __str__() – For Readable (User-Friendly) Output
#
# - Used by the print() function or str().
#
# - Its goal is to return a nicely formatted, human-readable string.
#
# - Think of it as something you show to the end user.

# %% [markdown]
# __repr__() – For Debugging (Developer-Friendly) Output
#
# - Used by the repr() function or the interactive interpreter.
#
# - Its goal is to return a detailed and unambiguous string, ideally one that could recreate the object if evaluated.
#
# - Think of it as something you show to a developer for debugging.

# %% [markdown]
# 20.  What is the significance of the ‘super()’ function in Python?

# %% [markdown]
# - he super() function in Python is used to call a method from a parent (superclass) inside a child (subclass).
#
# **It allows you to:**
#
# - Access and use methods or constructors of the parent class,
#
# - Without having to explicitly name the parent class.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python?

# %% [markdown]
# - The __del__() method is a special (dunder) method in Python that is called when an object is about to be destroyed, i.e., when it is garbage collected.
#
# - It is the destructor of a class, used to perform cleanup actions like closing files, releasing resources, or logging.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?

# %% [markdown]
# - **Static Method** : Defines a method that does not access the instance (self) or class (cls). It behaves like a regular function inside the class.
# - **class method** : Defines a method that takes the class (cls) as the first argument, not the instance. Can access or modify class-level variables.

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?

# %% [markdown]
# - When combined with inheritance, polymorphism lets a child class override a parent class method, and the same method call behaves differently depending on the object type.
# - Parent class defines a method.
#
# - Child class inherits the parent and may override the method.
#
# - Objects of child class can be treated as parent class objects, but their own method is called at runtime.
#
# - This is called runtime polymorphism or method overriding.

# %% [markdown]
# 24. What is method chaining in Python OOP?

# %% [markdown]
# - Method chaining is the practice of calling multiple methods on the same object sequentially in a single line.

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?

# %% [markdown]
# - The __call__() method is a special (dunder) method that allows an object of a class to be called like a function.
#
# In other words, when you use parentheses () after an object, Python internally calls the object’s __call__() method.

# %% [markdown]
# # **Practical Question**

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
# Parent class
class Animal:
    def speak(self):
        print("The animal makes a sound")

# Child class
class Dog(Animal):
    def speak(self):   # Overriding the parent method
        print("Bark!")

# Create objects
a = Animal()
d = Dog()

# Call the methods
a.speak()   # Output: The animal makes a sound
d.speak()   # Output: Bark!
# Out:
# The animal makes a sound
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod

# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass  # Abstract method (must be implemented by child classes)

# Derived class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

# Derived class: Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Create objects
circle = Circle(5)
rectangle = Rectangle(4, 6)

# Display areas
print("Area of Circle:", circle.area())
print("Area of Rectangle:", rectangle.area())
# Out:
# Area of Circle: 78.5
# Area of Rectangle: 24

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def show_type(self):
        print(f"Vehicle type: {self.vehicle_type}")

# Derived class from Vehicle
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_car_info(self):
        print(f"Car brand: {self.brand}")

# Further derived class from Car
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def show_electric_car_info(self):
        print(f"Battery capacity: {self.battery_capacity} kWh")

# Create an object of ElectricCar
e_car = ElectricCar("Four-wheeler", "Tesla", 100)

# Access methods from all levels of inheritance
e_car.show_type()             # From Vehicle
e_car.show_car_info()         # From Car
e_car.show_electric_car_info() # From ElectricCar

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
# Base class
class Bird:
    def fly(self):
        print("Some birds can fly.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead.")

# Create objects of derived classes
bird1 = Sparrow()
bird2 = Penguin()

# Demonstrate polymorphism
for bird in (bird1, bird2):
    bird.fly()
# Out:
# Sparrow flies high in the sky.
# Penguins cannot fly, they swim instead.

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
# Class demonstrating encapsulation
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ₹{amount}")
        else:
            print("Deposit amount must be positive!")

    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ₹{amount}")
        else:
            print("Insufficient balance or invalid amount!")

    # Method to check balance
    def get_balance(self):
        print(f"Current balance: ₹{self.__balance}")

# Create an object of BankAccount
account = BankAccount(5000)

# Perform operations
account.deposit(2000)
account.withdraw(1500)
account.get_balance()

# Trying to access private variable directly (will fail)
# print(account.__balance)  # ❌ AttributeError
# Out:
# Deposited: ₹2000
# Withdrew: ₹1500
# Current balance: ₹5500

# %% [markdown]
# 6.  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play()

# %%
# Base class
class Instrument:
    def play(self):
        print("Playing an instrument.")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar strings.")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Pressing the piano keys.")

# Function demonstrating runtime polymorphism
def start_playing(instrument):
    instrument.play()  # Calls the appropriate version at runtime

# Create objects of derived classes
guitar = Guitar()
piano = Piano()

# Call function with different objects
start_playing(guitar)
start_playing(piano)
# Out:
# Strumming the guitar strings.
# Pressing the piano keys.

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    # Class method to add two numbers
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method to subtract two numbers
    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Using the class method and static method
sum_result = MathOperations.add_numbers(10, 5)
difference_result = MathOperations.subtract_numbers(10, 5)

print(f"Sum: {sum_result}")
print(f"Difference: {difference_result}")
# Out:
# Sum: 15
# Difference: 5

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    # Class variable to count number of persons
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1  # Increment count whenever a new object is created

    # Class method to get total count
    @classmethod
    def get_person_count(cls):
        print(f"Total persons created: {cls.count}")


# Creating Person objects
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

# Using class method to display total count
Person.get_person_count()
# Out:
# Total persons created: 3

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Override the __str__() method
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# Create Fraction objects
f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

# Display fractions
print(f1)
print(f2)
# Out:
# 3/4
# 5/8

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
# Class to demonstrate operator overloading
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Override the + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # Override __str__ for easy display
    def __str__(self):
        return f"Vector({self.x}, {self.y})"


# Create two vector objects
v1 = Vector(2, 4)
v2 = Vector(5, -1)

# Add two vectors using overloaded +
result = v1 + v2

# Display result
print("v1 =", v1)
print("v2 =", v2)
print("Result =", result)
# Out:
# v1 = Vector(2, 4)
# v2 = Vector(5, -1)
# Result = Vector(7, 3)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


# Create Person objects
p1 = Person("karan", 25)
p2 = Person("Bobby", 30)

# Call the greet method
p1.greet()
p2.greet()
# Out:
# Hello, my name is karan and I am 25 years old.
# Hello, my name is Bobby and I am 30 years old.

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # List of grades

    def average_grade(self):
        if len(self.grades) == 0:
            return 0  # Handle empty grade list
        return sum(self.grades) / len(self.grades)


# Create Student objects
s1 = Student("sudhir", [85, 90, 78])
s2 = Student("sonu", [92, 88, 95])

# Display average grades
print(f"{s1.name}'s average grade: {s1.average_grade():.2f}")
print(f"{s2.name}'s average grade: {s2.average_grade():.2f}")
# Out:
# sudhir's average grade: 84.33
# sonu's average grade: 91.67

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    # Method to set dimensions
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate area
    def area(self):
        return self.length * self.width


# Create a Rectangle object
rect = Rectangle()

# Set dimensions
rect.set_dimensions(5, 3)

# Calculate and display area
print(f"Area of the rectangle: {rect.area()}")
# Out:
# Area of the rectangle: 15

# %%
14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary

# %%
# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    # Method to calculate salary
    def calculate_salary(self):
        salary = self.hours_worked * self.hourly_rate
        return salary

# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    # Override to include bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()
        total_salary = base_salary + self.bonus
        return total_salary


# Create Employee and Manager objects
emp = Employee("Alice", 160, 25)
mgr = Manager("Bob", 160, 30, 2000)

# Display salaries
print(f"{emp.name}'s salary: ₹{emp.calculate_salary()}")
print(f"{mgr.name}'s salary: ₹{mgr.calculate_salary()}")
# Out:
# Alice's salary: ₹4000
# Bob's salary: ₹6800

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity


# Create Product objects
p1 = Product("Laptop", 50000, 2)
p2 = Product("Mouse", 500, 5)

# Display total prices
print(f"Total price of {p1.name}: ₹{p1.total_price()}")
print(f"Total price of {p2.name}: ₹{p2.total_price()}")
# Out:
# Total price of Laptop: ₹100000
# Total price of Mouse: ₹2500

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass  # Abstract method must be implemented by subclasses

# Derived class Cow
class Cow(Animal):
    def sound(self):
        print("Cow says: Moo!")

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        print("Sheep says: Baa!")


# Create objects
cow = Cow()
sheep = Sheep()

# Call sound method
cow.sound()
sheep.sound()
# Out:
# Cow says: Moo!
# Sheep says: Baa!

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to get book information
    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


# Create Book objects
b1 = Book("godan", "Munshi premcand", 1936)
b2 = Book("Two state", "Chetan Bhagat", 2009)

# Display book information
print(b1.get_book_info())
print(b2.get_book_info())
# Out:
# 'godan' by Munshi premcand, published in 1936
# 'Two state' by Chetan Bhagat, published in 2009

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_info(self):
        return f"House at {self.address}, priced at ₹{self.price}"


# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_info(self):
        return f"Mansion at {self.address}, priced at ₹{self.price}, with {self.number_of_rooms} rooms"


# Create objects
house = House("123 Main St", 50000)
mansion = Mansion("456 Luxury Ave", 250000, 10)

# Display information
print(house.get_info())
print(mansion.get_info())
# Out:
# House at 123 Main St, priced at ₹50000
# Mansion at 456 Luxury Ave, priced at ₹250000, with 10 rooms

# %% [markdown]
# -

# %% [markdown]
# -

# %% [markdown]
# -
